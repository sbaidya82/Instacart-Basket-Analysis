# %% [markdown]
# # Import Libraries

# %%
# Import Libraries
import pandas as pd
import pickle
import numpy as np
import os

# %% [markdown]
# # Create Path

# %%
# Create path
path=r'C:\Users\baidy\Downloads\11-2024 Instacart Basket Analysis'

# %% [markdown]
# # Import Dataframe

# %%
# Import dataframe
ords_prods_merge=pd.read_pickle(os.path.join(path,'02 Data','Prepared Data','ords_prods_merge.pkl'))

# %%
# Create subset for first 1 million rows
df=ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 15)

# %%
# Define a function
def price_label(row):
    if row['prices']<=5:
        return 'Low-range product'
    elif(row['prices']>5) and (row['prices']<=15):
        return 'Mid_range product'
    elif row['prices']>15:
        return 'High range product'
    else: return np.nan

# %%
# Apply the fuction
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# C:\Users\baidy\AppData\Local\Temp\ipykernel_17772\1784858302.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df['price_range'].value_counts(dropna=False)
# Out:
# price_range
# Mid_range product     673340
# Low-range product     314392
# High range product     12268
# Name: count, dtype: int64

# %%
# check the most expensive product in the subset
df['prices'].max()
# Out:
# 25.0

# %%
# IF statement with the "loc" function
df.loc[df['prices']> 15, 'price_range_loc'] ='High range product'
df.loc[(df['prices']<= 15) & (df['prices']>5), 'price_range_loc']='Mid range product'
df.loc[df['prices']<= 5, 'price_range_loc']='Low range product'
df['price_range_loc'].value_counts(dropna=False)
# Out:
# C:\Users\baidy\AppData\Local\Temp\ipykernel_17772\148268331.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['prices']> 15, 'price_range_loc'] ='High range product'
# price_range_loc
# Mid range product     673340
# Low range product     314392
# High range product     12268
# Name: count, dtype: int64

# %%
# IF statement with "loc" function for "ords_prods_merge" dataframe
ords_prods_merge.loc[ords_prods_merge['prices']> 15, 'price_range_loc'] = 'High range product'
ords_prods_merge.loc[(ords_prods_merge['prices'] <= 15) & (ords_prods_merge['prices']>5), 'price_range_loc']= 'Mid range product'
ords_prods_merge.loc[ords_prods_merge['prices'] <= 5, 'price_range_loc'] = 'Low range product'
ords_prods_merge['price_range_loc'].value_counts(dropna = False)
# Out:
# price_range_loc
# Mid range product     21865987
# Low range product     10126321
# High range product      412551
# Name: count, dtype: int64

# %%
# If statement with for-loops ( my age is "X" for ages 30 to 45)
for x in range (30,45):
    print("My age is %d" %(x))
# Out:
# My age is 30
# My age is 31
# My age is 32
# My age is 33
# My age is 34
# My age is 35
# My age is 36
# My age is 37
# My age is 38
# My age is 39
# My age is 40
# My age is 41
# My age is 42
# My age is 43
# My age is 44

# %%
# Frequency of the column"orders_day_of_week"
ords_prods_merge['orders_day_of_week']. value_counts(dropna = False)
# Out:
# orders_day_of_week
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: count, dtype: int64

# %%
# for-loop for the column "orders_day_of_week"
result=[]
for value in ords_prods_merge["orders_day_of_week"]:
    if value==0:
        result.append("Busiest day")
    elif value==4:
        result.append("Least busy")
    else:
        result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
# Create new column in the dataframe "ords_prods_merge" set it equal to "result"
ords_prods_merge['busiest_day']=result

# %%
ords_prods_merge['busiest_day'].value_counts(dropna=False)
# Out:
# busiest_day
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: count, dtype: int64

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both
#
# ...

# %%
ords_prods_merge=ords_prods_merge.drop(columns=['Busiest days'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 ords_prods_merge=ords_prods_merge.drop(columns=['Busiest days'])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
# ...

# %%
ords_prods_merge.head()

# %% [markdown]
# # 02. Create new column "Busiest days"

# %%
# rename the column
ords_prods_merge.rename(columns={'busiest_day':'Busiest days'},inplace=True)

# %%
# Check the dataframe
ords_prods_merge.head()

# %% [markdown]
# # create new labels according to the clints wish

# %%
#creating the lebels
result1=[]
for value in ords_prods_merge['orders_day_of_week']:
    if value<=1:
        result1.append("Busiest days")
    elif value==4:
        result1.append("slowest days")
    elif value==3:
        result1.append("slowest days")
    else:
        result1.append("Regularly busy days")

# %%
result1

# %%
ords_prods_merge['Busiest days']=result1

# %%
# Frequency check 
ords_prods_merge['Busiest days'].value_counts(dropna=False)

# %% [markdown]
# # 03. Observation:
#  After creating the new column " Busiest days"  the most 2 busiest days in a week are Saturdays and Sundays , and the total orders are 11864412. The most slowest orders  days in a week are Tuesday and Thursday, and the total orders are 7624336.

# %% [markdown]
# # 04. create new column "busiest_period_of_day"

# %%
#frequency of the column "order_hour_of_day"
ords_prods_merge['order_hour_of_day'].value_counts(dropna=False)

# %%
# order_hour_of_day result
result2=[]
for value in ords_prods_merge["order_hour_of_day"]:
    if value==5:
        result2.append("Fewest orders")
    elif value==4:
        result2.append("Fewest orders")
    elif value==3:
        result2.append("Fewest orders")
    elif value==2:
        result2.append("Fewest orders")
    elif value<=1:
        result2.append("Average orders")
    elif value==6:
        result2.append("Average orders")
    elif value==7:
        result2.append("Average orders")
    elif value==20:
        result2.append("Average orders")
    elif value==21:
        result2.append("Average orders")
    elif value==22:
        result2.append("Average orders")
    elif value==23:
        result2.append("Average orders")
    else:
        result2.append("Most orders")

# %%
result2

# %%
# Create new column "busiest_period_of_day" in dataframe ords_prods_merge
ords_prods_merge['busiest_period_of_day']=result2

# %%
#check the new column
ords_prods_merge['busiest_period_of_day'].value_counts(dropna=False)

# %%
print('busiest_period_of_day')

# %% [markdown]
# # 07: Export the dataframe

# %%
# Export the dataframe 
ords_prods_merge.to_pickle(os.path.join(path,'02 Data','Prepared Data','ords_prods_merge.pkl'))
